# %%
from os import name

import requests


baseUrl = "https://vivenu.com/api/"

def getEventsPerSeller(token):
    #print(f"Token received: '{token}'")
    headers = {"Authorization": f"Bearer {token}"}
    response = requests.get(url=f"{baseUrl}events?top=1000&skip=0", headers=headers)

    if response.status_code == 200:
        #print(response.json())
        print("Repsonse received")
        return response.json()

    else:
        print(f"Error: {response.status_code}")
        print(f"Status: {response.status_code}")
        print(f"Response: {response.text}")
        return None

# %%
import httpRequests as http
import eventResponse as event

test_key = "key_674285ea23414d0f482c5baaa2d11eb99241707cff12665f344528dfd414a2629b3010369f9a7414851551bf1f41cd73";

def getDataForSeller(token):
    data = http.getEventsPerSeller(token)
    return event.map_events(data)


mapped_events = getDataForSeller(test_key)

print(mapped_events["events"][0]["name"])
# Out:
# Repsonse received
# FIF vs. SønderjyskE

# %%
import pandas as pd

eventsDF = pd.DataFrame(mapped_events["events"])

# %%
eventsDF.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               27 non-null     str
#  1   seller_id        27 non-null     str
#  2   name             27 non-null     str
#  3   event_type       27 non-null     str
#  4   start            27 non-null     str
#  5   end              27 non-null     str
#  6   timezone         27 non-null     str
#  7   sell_start       27 non-null     str
#  8   sell_end         27 non-null     str
#  9   location         27 non-null     object
#  10  image            26 non-null     str
#  11  url              27 non-null     str
#  12  max_amount       27 non-null     int64
#  13  max_per_order    27 non-null     int64
#  14  min_per_order    27 non-null     int64
#  15  hide_in_listing  27 non-null     bool
#  16  child_events     27 non-null     object
#  17  tickets          27 non-null     object
#  18  categories       27 non-null     object
#  19  created_at       27 non-null     str
#  20  updated_at       27 non-null     str
# dtypes: bool(1), int64(3), object(4), str(13)
# memory usage: 4.4+ KB
